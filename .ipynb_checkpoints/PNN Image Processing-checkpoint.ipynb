# %%
import os
import os.path as op
import boto3
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import skimage.io
import skimage.filters
from skimage.filters import try_all_threshold
#from diff_classifier import aws
import matplotlib.image as mpimg
from scipy import ndimage as ndi
from skimage.transform import resize

# %%
img = skimage.io.imread('slide_9_slice_2_60x_z_stack_2.tif')
img.shape
imgplot = plt.imshow(img[15, :, :], cmap='Greys')
plt.show()
imgplot = plt.imshow(img[16, :, :], cmap='Greys')
plt.show()
imgplot = plt.imshow(img[17, :, :], cmap='Greys')
plt.show()

# %%
img.shape
len(img)
# Out:
# 84

# %%
i = 0
DAPI_img = np.array

for z in range(0,len(img)):
    if i == 0:
        DAPI_img = img[z]
    if i == 1:
        PNN_img = img[z]
    if i == 2:
        PVA_img = img[z]
    i = i + 1
    if i > 2:
        i = 0

# %%
DAPI_img
# Out:
# array([[ 57,  41,  53, ..., 166,  86,  58],
#        [ 53,  38,  49, ..., 147, 150,  99],
#        [ 69,  57,  69, ..., 194, 200, 123],
#        ...,
#        [ 43,  58,  46, ...,  39,  68,  40],
#        [ 68,  57,  51, ...,  65,  65,  65],
#        [ 61,  53,  52, ...,  69,  72,  60]], dtype=uint16)

# %%
img_scaled = resize(img[0,:,:],(2048,2048))
scaled_plot = plt.imshow(img_scaled, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6db20ced51f9> in <module>
# ----> 1 img_scaled = resize(img[0,:,:],(2048,2048))
#       2 scaled_plot = plt.imshow(img_scaled, cmap='gray')
#       3 plt.show()
#
# NameError: name 'resize' is not defined

# %%
try_all_threshold(img_scaled, figsize=(20,18))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b55a7fd07100> in <module>
# ----> 1 try_all_threshold(img_scaled, figsize=(20,18))
#
# NameError: name 'try_all_threshold' is not defined

# %%
# This performs threshold without using a preprocessing median filtering technique

thresh = skimage.filters.threshold_otsu(img_scaled)
pnnbinary = img_scaled > thresh
binaryplot = plt.imshow(pnnbinary, cmap='gray')
plt.show()

pnnbinary_filled = ndi.binary_fill_holes(pnnbinary)
binary_filledplot = plt.imshow(pnnbinary_filled, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-453d032dc6ff> in <module>
#       1 # This performs threshold without using a preprocessing median filtering technique
#       2
# ----> 3 thresh = skimage.filters.threshold_otsu(img_scaled)
#       4 pnnbinary = img_scaled > thresh
#       5 binaryplot = plt.imshow(pnnbinary, cmap='gray')
#
# NameError: name 'skimage' is not defined

# %%
print(img[0,:,:])
print(pnnbinary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8eb93bda6f6d> in <module>
# ----> 1 print(img[0,:,:])
#       2 print(pnnbinary)
#
# NameError: name 'img' is not defined

# %%
from skimage import morphology

# %%
pnn_clean = morphology.remove_small_objects(pnnbinary_filled, min_size=3000)
pnn_clean_plot = plt.imshow(pnn_clean, cmap='gray')
plt.show()
binary_filledplot = plt.imshow(pnnbinary_filled, cmap='gray')
plt.show()
binaryplot = plt.imshow(pnnbinary, cmap='gray')
plt.show()

# %%
from scipy.ndimage.morphology import distance_transform_edt as Euclidean

euc_img = Euclidean(1-pnn_clean) #1- represents going outwards from the cells
plt.imshow(euc_img)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
euc_img
euc_img.min()
# Out:
# 0.0

# %%
import pandas as pd
bucket = 'mckenna.data'
remote_folder = '11_16_18_MPT_in_PNNs'
prefix = 'HBSS_vid_3'
filename = "msd_{}.csv".format(prefix)
aws.download_s3(remote_folder+'/'+filename, filename, bucket_name=bucket)
local_name = filename
merged = pd.read_csv(local_name)

# %%
merged[0:10]
# Out:
#    Unnamed: 0  Frame  Track_ID   X   Y       MSDs     Gauss  Quality  \
# 0           0    0.0       0.0 NaN NaN   0.000000  0.000000      NaN
# 1           1    1.0       0.0 NaN NaN   4.001641  2.396512      NaN
# 2           2    2.0       0.0 NaN NaN   6.834146  1.681477      NaN
# 3           3    3.0       0.0 NaN NaN   7.851303  1.606836      NaN
# 4           4    4.0       0.0 NaN NaN   8.840694  1.439491      NaN
# 5           5    5.0       0.0 NaN NaN  11.364362  1.123226      NaN
# 6           6    6.0       0.0 NaN NaN  12.743154  1.025701      NaN
# 7           7    7.0       0.0 NaN NaN  14.829385  0.891548      NaN
# 8           8    8.0       0.0 NaN NaN  15.837694  0.879375      NaN
# 9           9    9.0       0.0 NaN NaN  16.595764  0.835129      NaN
#
#    SN_Ratio  Mean_Intensity
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3       NaN             NaN
# 4       NaN             NaN
# 5       NaN             NaN
# 6       NaN             NaN
# 7       NaN             NaN
# 8       NaN             NaN
# 9       NaN             NaN

# %%
merged.X.max()
# Out:
# 2047.0

# %%
euc_img.shape
# Out:
# (512, 512)
